# %%
# !pip install smolagents[litellm]
from smolagents import CodeAgent, LiteLLMModel

model = LiteLLMModel(
    model_id="volcengine/doubao-1-5-pro-32k-250115", # This model is a bit weak for agentic behaviours though
    api_base="https://ark.cn-beijing.volces.com/api/v3", # replace with 127.0.0.1:11434 or remote open-ai compatible server if necessary
    api_key="ffd77d7c-f420-4b69-8557-80e7fa85c8b9", # replace with API key if necessary，写自己的key
)

# %%
from smolagents import tool

@tool
def model_download_tool(task: str) -> str:
    """
    This is a tool that returns the most downloaded model of a given task on the Hugging Face Hub.
    It returns the name of the checkpoint.

    Args:
        task: The task for which to get the download count.
    """
    id = "100"
    return id

# %%
from smolagents import CodeAgent
agent = CodeAgent(tools=[model_download_tool], model=model)
agent.run(
    "Can you give me the name of the model that has the most downloads in the 'text-to-video' task on the Hugging Face Hub?"
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Can you give me the name of the model that has the most downloads in the 'text-to-video' task on the Hugging    │
# │ Face Hub?                                                                                                       │
# │                                                                                                                 │
# ╰─ LiteLLMModel - volcengine/doubao-1-5-pro-32k-250115 ───────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   model_name = model_download_tool(task="text-to-video")
#   final_answer(model_name)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: 100
# [Step 1: Duration 23.61 seconds| Input tokens: 2,268 | Output tokens: 64]
# '100'

# %%
import my_tools
agent = CodeAgent(tools=[my_tools.my_count], model=model)
agent.run(
    "Can you give me the name of the model that has the most downloads in the 'text-to-video' task on the Hugging Face Hub?"
)
# Out:
#   Cell In[7], line 2
#     agent = CodeAgent(tools=[my_tools.*], model=model)
#                                       ^
# SyntaxError: invalid syntax

# %%
import airsim_w2
agent = CodeAgent(tools=[airsim_w2.takeoff], model=model)
agent.run(
    "Can you give me the name of the model that has the most downloads in the 'text-to-video' task on the Hugging Face Hub?"
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Can you give me the name of the model that has the most downloads in the 'text-to-video' task on the Hugging    │
# │ Face Hub?                                                                                                       │
# │                                                                                                                 │
# ╰─ LiteLLMModel - volcengine/doubao-1-5-pro-32k-250115 ───────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   model_name = takeoff(task="text-to-video")
#   final_answer(model_name)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: 100
# [Step 1: Duration 2.66 seconds| Input tokens: 2,267 | Output tokens: 63]
# '100'

# %%
import airsim_w2
agent = CodeAgent(tools=[airsim_w2.takeoff], model=model)
agent.run(
    "起飞"
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ 起飞                                                                                                            │
# │                                                                                                                 │
# ╰─ LiteLLMModel - volcengine/doubao-1-5-pro-32k-250115 ───────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   takeoff_result = takeoff()
#   print(takeoff_result)
#   final_answer(takeoff_result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Connected!
# Client Ver:1 (Min Req: 1), Server Ver:1 (Min Req: 1)
# Execution logs:
# 成功
#
# Out - Final answer: 成功
# [Step 1: Duration 38.58 seconds| Input tokens: 2,198 | Output tokens: 68]
# '成功'

# %%
import airsim_w2
agent = CodeAgent(tools=[airsim_w2.takeoff,airsim_w2.land], model=model)
agent.run(
    "请先起飞无人机，然后停留3s，然后再降落"
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ 请先起飞无人机，然后停留3s，然后再降落                                                                          │
# │                                                                                                                 │
# ╰─ LiteLLMModel - volcengine/doubao-1-5-pro-32k-250115 ───────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import time
#   takeoff_result = takeoff()
#   print("起飞结果:", takeoff_result)
#   time.sleep(3)
#   land_result = land()
#   final_answer(f"起飞结果: {takeoff_result}, 降落结果: {land_result}")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Connected!
# Client Ver:1 (Min Req: 1), Server Ver:1 (Min Req: 1)
# Execution logs:
# 起飞结果: 成功
#
# Out - Final answer: 起飞结果: 成功, 降落结果: 成功
# [Step 1: Duration 33.51 seconds| Input tokens: 2,241 | Output tokens: 117]
# '起飞结果: 成功, 降落结果: 成功'
